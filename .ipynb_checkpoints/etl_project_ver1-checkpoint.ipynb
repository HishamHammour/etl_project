# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file1 = "Resources/education-income.csv"
education_data_df = pd.read_csv(csv_file1)
education_data_df.head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#   Total Pop, 25 and older (2010)  \
# 0                            609
# 1                            239
# 2                          1,729
# 3                          1,232
# 4                            166
#
#   Edu. Attainment: Less than High School (2010)  \
# 0                                         18.7%
# 1                                          9.2%
# 2                                         23.0%
# 3                                         14.9%
# 4                                         18.1%
#
#   Edu. Attainment: High School Graduate (2010)  \
# 0                                        44.5%
# 1                                        28.9%
# ...

# %%
education_data_df.columns
# Out:
# Index(['Neighborhood', 'Sector #', 'Population (2010)',
#        'Total Pop, 25 and older (2010)',
#        'Edu. Attainment: Less than High School (2010)',
#        'Edu. Attainment: High School Graduate (2010)',
#        'Edu. Attainment: Assoc./Prof. Degree (2010)',
#        'Edu. Attainment: Bachelor's Degree (2010)',
#        'Edu. Attainment: Postgraduate Degree (2010)',
#        '1999 Median Income ('99 Dollars)', '2009 Median Income ('09 Dollars)',
#        '1999 Median Income ('11 Dollars)', '2009 Med. Income ('13 Dollars)',
#        'Est. Pop. for which Poverty Calc. (2010)',
#        'Est. Pop. Under Poverty (2010)', 'Est. Percent Under Poverty (2010)'],
#       dtype='object')

# %% [markdown]
# # Create new data with select columns

# %%
new_edu_data_df = education_data_df[["Neighborhood", "Sector #", "Population (2010)",
       "Total Pop, 25 and older (2010)",
       "Edu. Attainment: Less than High School (2010)",
       "Edu. Attainment: High School Graduate (2010)",
       "Edu. Attainment: Assoc./Prof. Degree (2010)",
       "Edu. Attainment: Bachelor's Degree (2010)",
       "Edu. Attainment: Postgraduate Degree (2010)",
       "Est. Pop. for which Poverty Calc. (2010)",
       "Est. Pop. Under Poverty (2010)", "Est. Percent Under Poverty (2010)"]].copy()
new_edu_data_df.head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#   Total Pop, 25 and older (2010)  \
# 0                            609
# 1                            239
# 2                          1,729
# 3                          1,232
# 4                            166
#
#   Edu. Attainment: Less than High School (2010)  \
# 0                                         18.7%
# 1                                          9.2%
# 2                                         23.0%
# 3                                         14.9%
# 4                                         18.1%
#
#   Edu. Attainment: High School Graduate (2010)  \
# 0                                        44.5%
# 1                                        28.9%
# ...

# %%
csv_file2 = "Resources/employment.csv"
employment_data_df = pd.read_csv(csv_file2)
employment_data_df.head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#   Total Age 16+ N'hood Residents Employed (2010 Est.)  \
# 0                                                386
# 1                                                151
# 2                                                858
# 3                                                685
# 4                                                 72
#
#   Resident Jobs: Construction Resident Jobs: Manufacturing  \
# 0                        3.1%                         1.8%
# 1                        0.0%                         6.6%
# 2                        4.2%                         7.8%
# 3                        7.2%                        13.0%
# ...

# %%
# employment_data_df.columns

# %% [markdown]
# # Create new data with select columns

# %%
new_emp_data_df = employment_data_df[["Neighborhood", "Sector #", "Population (2010)",
       "Total Age 16+ N'hood Residents Employed (2010 Est.)"]]
new_emp_data_df.head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#   Total Age 16+ N'hood Residents Employed (2010 Est.)
# 0                                                386
# 1                                                151
# 2                                                858
# 3                                                685
# 4                                                 72

# %% [markdown]
# # Creating the DataBase

# %%
import pymysql.cursors

# %%
connection = pymysql.connect(host= "localhost",
                                       user= "root",
                                       port=3306,
                                       password="Hmsh12004!")

# %%
# Creating the Database
try:
    with connection.cursor() as cursor:
        cursor.execute("CREATE DATABASE Edu_and_Emp_db")
finally:
    connection.close()

# %% [markdown]
# # Connect to local database

# %%
rds_connection_string = "root:Hmsh12004!@localhost:3306/Edu_and_Emp_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %% [markdown]
# # Use pandas to load csv converted DataFrames into database

# %%
new_edu_data_df.to_sql(name='education_data',  con=engine, if_exists='append', index=False)

# %%
new_emp_data_df.to_sql(name='employment_data',  con=engine, if_exists='append', index=False)

# %% [markdown]
# # Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from education_data', con=engine).head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#   Total Pop, 25 and older (2010)  \
# 0                            609
# 1                            239
# 2                          1,729
# 3                          1,232
# 4                            166
#
#   Edu. Attainment: Less than High School (2010)  \
# 0                                         18.7%
# 1                                          9.2%
# 2                                         23.0%
# 3                                         14.9%
# 4                                         18.1%
#
#   Edu. Attainment: High School Graduate (2010)  \
# 0                                        44.5%
# 1                                        28.9%
# ...

# %%
pd.read_sql_query('select * from employment_data', con=engine).head()
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
#
#   Total Age 16+ N'hood Residents Employed (2010 Est.)
# 0                                                386
# 1                                                151
# 2                                                858
# 3                                                685
# 4                                                 72
